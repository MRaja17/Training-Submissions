# %% [markdown]
# # Intermediate 1: Real Dataset – Advanced SQL Joins & Aggregations
#
# This notebook will load a real dataset and apply:
# - SQL-like joins using pandas.merge()
# - Aggregations using groupby()
# - Analysis and explanation
