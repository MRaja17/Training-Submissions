# %% [markdown]
# # Hard 2: Mini Project – Advanced SQL Joins & Aggregations
#
# This notebook demonstrates an end-to-end mini project applying SQL-like joins, aggregations, and analysis using Python (pandas).

# %%
# Import required libraries
import pandas as pd

print('Libraries loaded successfully!')
